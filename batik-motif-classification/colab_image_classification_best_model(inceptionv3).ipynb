# %% [markdown]
# ### **Import Resource**

# %%
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading https://files.pythonhosted.org/packages/28/5a/2497b3ba86f5f1c2c7539e0bc5d957146a5ed71acfb6c66f644974af4309/tensorflowjs-3.6.0-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 5.0MB/s
# Requirement already satisfied: tensorflow<3,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (2.5.0)
# Collecting tensorflow-hub<0.10,>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/ac/83/a7df82744a794107641dad1decaad017d82e25f0e1f761ac9204829eef96/tensorflow_hub-0.9.0-py2.py3-none-any.whl (103kB)
#      |████████████████████████████████| 112kB 9.9MB/s
# Requirement already satisfied: six<2,>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (1.15.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.19.5)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0.dev2021032900)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.12.4)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.34.1)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12.1)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.12.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.7.4.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.36.2)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow<3,>=2.1.0->tensorflowjs) (1.5.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (56.1.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.30.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.10)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.1.0)
# Installing collected packages: tensorflow-hub, tensorflowjs
#   Found existing installation: tensorflow-hub 0.12.0
#     Uninstalling tensorflow-hub-0.12.0:
#       Successfully uninstalled tensorflow-hub-0.12.0
# Successfully installed tensorflow-hub-0.9.0 tensorflowjs-3.6.0

# %%
import tensorflow as tf
print('TensorFlow :', tf.__version__)
# Out:
# TensorFlow : 2.5.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras import layers
from tensorflow.keras import Model
from keras_preprocessing import image
from shutil import copyfile
from google.colab import files

import zipfile
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# ### **Mounting Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Dataset Directory**

# %%
try:
    os.mkdir('/content/drive/Shareddrives/Capstone Project/batik2/')
    os.mkdir(os.path.join('/content/drive/Shareddrives/Capstone Project/batik2/', 'training'))
    os.mkdir(os.path.join('/content/drive/Shareddrives/Capstone Project/batik2/', 'testing'))
    os.mkdir(os.path.join('/content/drive/Shareddrives/Capstone Project/batik2/training', 'ceplok'))
    os.mkdir(os.path.join('/content/drive/Shareddrives/Capstone Project/batik2/training', 'megamendung'))
    os.mkdir(os.path.join('/content/drive/Shareddrives/Capstone Project/batik2/training', 'kawung'))
    os.mkdir(os.path.join('/content/drive/Shareddrives/Capstone Project/batik2/training', 'parang'))
    os.mkdir(os.path.join('/content/drive/Shareddrives/Capstone Project/batik2/training', 'sidomukti'))
    os.mkdir(os.path.join('/content/drive/Shareddrives/Capstone Project/batik2/testing', 'ceplok'))
    os.mkdir(os.path.join('/content/drive/Shareddrives/Capstone Project/batik2/testing', 'megamendung'))
    os.mkdir(os.path.join('/content/drive/Shareddrives/Capstone Project/batik2/testing', 'kawung'))
    os.mkdir(os.path.join('/content/drive/Shareddrives/Capstone Project/batik2/testing', 'parang'))
    os.mkdir(os.path.join('/content/drive/Shareddrives/Capstone Project/batik2/testing', 'sidomukti'))
except OSError:
    pass

# %%
print('Colab3 Ceplok:', len(os.listdir('/content/drive/Shareddrives/Capstone Project/Dataset/Main Dataset/Colab3/Ceplok/')))
print('Colab3 Megamendung:', len(os.listdir('/content/drive/Shareddrives/Capstone Project/Dataset/Main Dataset/Colab3/Megamendung/')))
print('Colab3 Kawung:', len(os.listdir('/content/drive/Shareddrives/Capstone Project/Dataset/Main Dataset/Colab3/Kawung/')))
print('Colab3 Parang:', len(os.listdir('/content/drive/Shareddrives/Capstone Project/Dataset/Main Dataset/Colab3/Parang/')))
print('Colab3 Sidomukti:', len(os.listdir('/content/drive/Shareddrives/Capstone Project/Dataset/Main Dataset/Colab3/Sidomukti/')))
# Out:
# Colab3 Ceplok: 708
# Colab3 Megamendung: 560
# Colab3 Kawung: 661
# Colab3 Parang: 922
# Colab3 Sidomukti: 267

# %% [markdown]
# ### **Split Dataset**

# %%
def split_data(SOURCE, TRAINING, TESTING, VALIDATION, SPLIT_SIZE):
    # YOUR CODE STARTS HERE
    if not os.path.exists(TRAINING): 
        os.makedirs(TRAINING) 
                
    if not os.path.exists(TESTING): 
        os.makedirs(TESTING) 

    if not os.path.exists(VALIDATION): 
        os.makedirs(VALIDATION)

    file_names = os.listdir(SOURCE) 
    file_number = len(file_names) 

    for index, file in enumerate(file_names): 
        if index < SPLIT_SIZE * file_number: 
          if index < 0.8 * file_number:
            copyfile(os.path.join(SOURCE, file), os.path.join(TRAINING, file))
          else:
            copyfile(os.path.join(SOURCE, file), os.path.join(VALIDATION, file))
        else: 
            copyfile(os.path.join(SOURCE, file), os.path.join(TESTING, file)) 
        
CEPLOK_SOURCE_DIR = "/content/drive/Shareddrives/Capstone Project/Dataset/Main Dataset/Colab3/Ceplok/"
MEGAMENDUNG_SOURCE_DIR = "/content/drive/Shareddrives/Capstone Project/Dataset/Main Dataset/Colab3/Megamendung/"
KAWUNG_SOURCE_DIR = "/content/drive/Shareddrives/Capstone Project/Dataset/Main Dataset/Colab3/Kawung/"
PARANG_SOURCE_DIR = "/content/drive/Shareddrives/Capstone Project/Dataset/Main Dataset/Colab3/Parang/"
SIDOMUKTI_SOURCE_DIR = "/content/drive/Shareddrives/Capstone Project/Dataset/Main Dataset/Colab3/Sidomukti/"

TRAINING_CEPLOK_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/training/ceplok/"
TRAINING_MEGAMENDUNG_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/training/megamendung/"
TRAINING_KAWUNG_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/training/kawung/"
TRAINING_PARANG_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/training/parang/"
TRAINING_SIDOMUKTI_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/training/sidomukti/"

TESTING_CEPLOK_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/testing/ceplok/"
TESTING_MEGAMENDUNG_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/testing/megamendung/"
TESTING_KAWUNG_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/testing/kawung/"
TESTING_PARANG_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/testing/parang/"
TESTING_SIDOMUKTI_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/testing/sidomukti/"

VALIDATION_CEPLOK_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/validation/ceplok/"
VALIDATION_MEGAMENDUNG_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/validation/megamendung/"
VALIDATION_KAWUNG_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/validation/kawung/"
VALIDATION_PARANG_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/validation/parang/"
VALIDATION_SIDOMUKTI_DIR = "/content/drive/Shareddrives/Capstone Project/batik2/validation/sidomukti/"


split_size = .9
split_data(CEPLOK_SOURCE_DIR, TRAINING_CEPLOK_DIR, TESTING_CEPLOK_DIR, VALIDATION_CEPLOK_DIR, split_size)
split_data(MEGAMENDUNG_SOURCE_DIR, TRAINING_MEGAMENDUNG_DIR, TESTING_MEGAMENDUNG_DIR, VALIDATION_MEGAMENDUNG_DIR, split_size)
split_data(KAWUNG_SOURCE_DIR, TRAINING_KAWUNG_DIR, TESTING_KAWUNG_DIR, VALIDATION_KAWUNG_DIR, split_size)
split_data(PARANG_SOURCE_DIR, TRAINING_PARANG_DIR, TESTING_PARANG_DIR, VALIDATION_PARANG_DIR, split_size)
split_data(SIDOMUKTI_SOURCE_DIR, TRAINING_SIDOMUKTI_DIR, TESTING_SIDOMUKTI_DIR, VALIDATION_SIDOMUKTI_DIR, split_size)

# %%
train_ceplok = os.listdir(TRAINING_CEPLOK_DIR)
train_megamendung = os.listdir(TRAINING_MEGAMENDUNG_DIR)
train_kawung = os.listdir(TRAINING_KAWUNG_DIR)
train_parang = os.listdir(TRAINING_PARANG_DIR)
train_sidomukti = os.listdir(TRAINING_SIDOMUKTI_DIR)

test_ceplok = os.listdir(TESTING_CEPLOK_DIR)
test_megamendung = os.listdir(TESTING_MEGAMENDUNG_DIR)
test_kawung = os.listdir(TESTING_KAWUNG_DIR)
test_parang = os.listdir(TESTING_PARANG_DIR)
test_sidomukti = os.listdir(TESTING_SIDOMUKTI_DIR)

val_ceplok = os.listdir(VALIDATION_CEPLOK_DIR)
val_megamendung = os.listdir(VALIDATION_MEGAMENDUNG_DIR)
val_kawung = os.listdir(VALIDATION_KAWUNG_DIR)
val_parang = os.listdir(VALIDATION_PARANG_DIR)
val_sidomukti = os.listdir(VALIDATION_SIDOMUKTI_DIR)

print("Training")
print('Ceplok :', len(train_ceplok))
print('Megamendung :', len(train_megamendung))
print('Kawung :', len(train_kawung))
print('Parang :', len(train_parang))
print('Sidomukti :', len(train_sidomukti))

print("\nTesting")
print('Ceplok :', len(test_ceplok))
print('Megamendung :', len(test_megamendung))
print('Kawung :', len(test_kawung))
print('Parang :', len(test_parang))
print('Sidomukti :', len(test_sidomukti))

print("\nValidation")
print('Ceplok :', len(val_ceplok))
print('Megamendung :', len(val_megamendung))
print('Kawung :', len(val_kawung))
print('Parang :', len(val_parang))
print('Sidomukti :', len(val_sidomukti))
# Out:
# Training
# Ceplok : 567
# Megamendung : 448
# Kawung : 529
# Parang : 738
# Sidomukti : 214
#
# Testing
# Ceplok : 70
# Megamendung : 56
# Kawung : 66
# Parang : 92
# Sidomukti : 26
#
# Validation
# Ceplok : 71
# Megamendung : 56
# Kawung : 66
# Parang : 92
# Sidomukti : 27

# %%
BATCH_SIZE = 32
IMG_SIZE = (224, 224)

TRAINING_DIR = '/content/drive/Shareddrives/Capstone Project/batik2/training/'
train_datagen = image.ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=45,
    width_shift_range=0.25,
    height_shift_range=0.25,
    shear_range=0.25,
    zoom_range=0.25,
    horizontal_flip=True,
    fill_mode='nearest'
)

train_generator = train_datagen.flow_from_directory(
    TRAINING_DIR, 
    class_mode='categorical', 
    batch_size=BATCH_SIZE, 
    target_size=IMG_SIZE, 
    shuffle=True
)


TESTING_DIR = '/content/drive/Shareddrives/Capstone Project/batik2/testing/'
datagen = image.ImageDataGenerator(rescale = 1.0/255.0)

test_generator = datagen.flow_from_directory(
    TESTING_DIR, 
    class_mode='categorical', 
    batch_size=BATCH_SIZE, 
    target_size=IMG_SIZE,
    shuffle=False
)


VALIDATION_DIR = '/content/drive/Shareddrives/Capstone Project/batik2/validation/'
val_generator = datagen.flow_from_directory(
    VALIDATION_DIR, 
    class_mode='categorical', 
    batch_size=BATCH_SIZE, 
    target_size=IMG_SIZE,
    shuffle=True
)
# Out:
# Found 2496 images belonging to 5 classes.
# Found 310 images belonging to 5 classes.
# Found 312 images belonging to 5 classes.

# %%
train_dataset = image_dataset_from_directory(TRAINING_DIR,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE)
# Out:
# Found 2496 files belonging to 5 classes.

# %%
class_names = train_dataset.class_names

print(class_names)
# Out:
# ['ceplok', 'kawung', 'megamendung', 'parang', 'sidomukti']

# %%
plt.figure(figsize=(13, 13))
for images, labels in train_dataset.take(1):
  for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### **Simple CNN**

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    # This is the first convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=IMG_SIZE + (3,)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    # Using dropouts
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(5, activation='softmax')
])

model.summary()

# %%
learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_generator,
                    epochs=10,
                    steps_per_epoch=len(train_generator),
                    validation_data=val_generator,
                    verbose = 1,
                    validation_steps=len(val_generator))

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc)) # Get number of epochs

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ### **Train Model with Transfer Learning**

# %%
pretrained_model = InceptionV3(input_shape = (224, 224, 3),
                                include_top = False,
                                weights = 'imagenet')

# %%
for layer in pretrained_model.layers:
    layer.trainable = False
    
# Print the model summary
#pretrained_model.summary()

# %%
last_layer = pretrained_model.get_layer('mixed5')
print('last layer output shape: ', last_layer.output_shape)
last_output = last_layer.output
# Out:
# last layer output shape:  (None, 12, 12, 768)

# %%
#model2 = tf.keras.Sequential([
#  pretrained_model,
#  tf.keras.layers.Flatten(),
#  tf.keras.layers.Dense(512, activation='relu'),
#  tf.keras.layers.Dropout(0.2),
#  tf.keras.layers.Dense(5, activation='softmax')
#])

# %%
# Flatten the output layer to 1 dimension
x = layers.Flatten()(last_output)
# Add a fully connected layer with 1,024 hidden units and ReLU activation
x = layers.Dense(512, activation='relu')(x)
# Add a dropout rate of 0.2
x = layers.Dropout(0.2)(x)                  
# Add a final sigmoid layer for classification
x = layers.Dense(5, activation='softmax')(x)

# %%
model2 = Model(pretrained_model.input, x)

# %%
model2.compile(optimizer=tf.keras.optimizers.Adam(0.0001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

model2.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_940 (Conv2D)             (None, 111, 111, 32) 864         input_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_940 (BatchN (None, 111, 111, 32) 96          conv2d_940[0][0]
# __________________________________________________________________________________________________
# activation_940 (Activation)     (None, 111, 111, 32) 0           batch_normalization_940[0][0]
# __________________________________________________________________________________________________
# conv2d_941 (Conv2D)             (None, 109, 109, 32) 9216        activation_940[0][0]
# __________________________________________________________________________________________________
# batch_normalization_941 (BatchN (None, 109, 109, 32) 96          conv2d_941[0][0]
# __________________________________________________________________________________________________
# activation_941 (Activation)     (None, 109, 109, 32) 0           batch_normalization_941[0][0]
# __________________________________________________________________________________________________
# conv2d_942 (Conv2D)             (None, 109, 109, 64) 18432       activation_941[0][0]
# __________________________________________________________________________________________________
# batch_normalization_942 (BatchN (None, 109, 109, 64) 192         conv2d_942[0][0]
# __________________________________________________________________________________________________
# activation_942 (Activation)     (None, 109, 109, 64) 0           batch_normalization_942[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_40 (MaxPooling2D) (None, 54, 54, 64)   0           activation_942[0][0]
# __________________________________________________________________________________________________
# conv2d_943 (Conv2D)             (None, 54, 54, 80)   5120        max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_943 (BatchN (None, 54, 54, 80)   240         conv2d_943[0][0]
# __________________________________________________________________________________________________
# activation_943 (Activation)     (None, 54, 54, 80)   0           batch_normalization_943[0][0]
# __________________________________________________________________________________________________
# conv2d_944 (Conv2D)             (None, 52, 52, 192)  138240      activation_943[0][0]
# __________________________________________________________________________________________________
# batch_normalization_944 (BatchN (None, 52, 52, 192)  576         conv2d_944[0][0]
# __________________________________________________________________________________________________
# activation_944 (Activation)     (None, 52, 52, 192)  0           batch_normalization_944[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_41 (MaxPooling2D) (None, 25, 25, 192)  0           activation_944[0][0]
# __________________________________________________________________________________________________
# conv2d_948 (Conv2D)             (None, 25, 25, 64)   12288       max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_948 (BatchN (None, 25, 25, 64)   192         conv2d_948[0][0]
# __________________________________________________________________________________________________
# activation_948 (Activation)     (None, 25, 25, 64)   0           batch_normalization_948[0][0]
# __________________________________________________________________________________________________
# conv2d_946 (Conv2D)             (None, 25, 25, 48)   9216        max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_949 (Conv2D)             (None, 25, 25, 96)   55296       activation_948[0][0]
# __________________________________________________________________________________________________
# batch_normalization_946 (BatchN (None, 25, 25, 48)   144         conv2d_946[0][0]
# __________________________________________________________________________________________________
# batch_normalization_949 (BatchN (None, 25, 25, 96)   288         conv2d_949[0][0]
# __________________________________________________________________________________________________
# activation_946 (Activation)     (None, 25, 25, 48)   0           batch_normalization_946[0][0]
# __________________________________________________________________________________________________
# activation_949 (Activation)     (None, 25, 25, 96)   0           batch_normalization_949[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_90 (AveragePo (None, 25, 25, 192)  0           max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_945 (Conv2D)             (None, 25, 25, 64)   12288       max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_947 (Conv2D)             (None, 25, 25, 64)   76800       activation_946[0][0]
# __________________________________________________________________________________________________
# conv2d_950 (Conv2D)             (None, 25, 25, 96)   82944       activation_949[0][0]
# __________________________________________________________________________________________________
# conv2d_951 (Conv2D)             (None, 25, 25, 32)   6144        average_pooling2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_945 (BatchN (None, 25, 25, 64)   192         conv2d_945[0][0]
# __________________________________________________________________________________________________
# batch_normalization_947 (BatchN (None, 25, 25, 64)   192         conv2d_947[0][0]
# __________________________________________________________________________________________________
# batch_normalization_950 (BatchN (None, 25, 25, 96)   288         conv2d_950[0][0]
# __________________________________________________________________________________________________
# batch_normalization_951 (BatchN (None, 25, 25, 32)   96          conv2d_951[0][0]
# __________________________________________________________________________________________________
# activation_945 (Activation)     (None, 25, 25, 64)   0           batch_normalization_945[0][0]
# __________________________________________________________________________________________________
# activation_947 (Activation)     (None, 25, 25, 64)   0           batch_normalization_947[0][0]
# __________________________________________________________________________________________________
# activation_950 (Activation)     (None, 25, 25, 96)   0           batch_normalization_950[0][0]
# __________________________________________________________________________________________________
# activation_951 (Activation)     (None, 25, 25, 32)   0           batch_normalization_951[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 25, 25, 256)  0           activation_945[0][0]
#                                                                  activation_947[0][0]
#                                                                  activation_950[0][0]
#                                                                  activation_951[0][0]
# __________________________________________________________________________________________________
# conv2d_955 (Conv2D)             (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_955 (BatchN (None, 25, 25, 64)   192         conv2d_955[0][0]
# __________________________________________________________________________________________________
# activation_955 (Activation)     (None, 25, 25, 64)   0           batch_normalization_955[0][0]
# __________________________________________________________________________________________________
# conv2d_953 (Conv2D)             (None, 25, 25, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_956 (Conv2D)             (None, 25, 25, 96)   55296       activation_955[0][0]
# __________________________________________________________________________________________________
# batch_normalization_953 (BatchN (None, 25, 25, 48)   144         conv2d_953[0][0]
# __________________________________________________________________________________________________
# batch_normalization_956 (BatchN (None, 25, 25, 96)   288         conv2d_956[0][0]
# __________________________________________________________________________________________________
# activation_953 (Activation)     (None, 25, 25, 48)   0           batch_normalization_953[0][0]
# __________________________________________________________________________________________________
# activation_956 (Activation)     (None, 25, 25, 96)   0           batch_normalization_956[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_91 (AveragePo (None, 25, 25, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_952 (Conv2D)             (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_954 (Conv2D)             (None, 25, 25, 64)   76800       activation_953[0][0]
# __________________________________________________________________________________________________
# conv2d_957 (Conv2D)             (None, 25, 25, 96)   82944       activation_956[0][0]
# __________________________________________________________________________________________________
# conv2d_958 (Conv2D)             (None, 25, 25, 64)   16384       average_pooling2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_952 (BatchN (None, 25, 25, 64)   192         conv2d_952[0][0]
# __________________________________________________________________________________________________
# batch_normalization_954 (BatchN (None, 25, 25, 64)   192         conv2d_954[0][0]
# __________________________________________________________________________________________________
# batch_normalization_957 (BatchN (None, 25, 25, 96)   288         conv2d_957[0][0]
# __________________________________________________________________________________________________
# batch_normalization_958 (BatchN (None, 25, 25, 64)   192         conv2d_958[0][0]
# __________________________________________________________________________________________________
# activation_952 (Activation)     (None, 25, 25, 64)   0           batch_normalization_952[0][0]
# __________________________________________________________________________________________________
# activation_954 (Activation)     (None, 25, 25, 64)   0           batch_normalization_954[0][0]
# __________________________________________________________________________________________________
# activation_957 (Activation)     (None, 25, 25, 96)   0           batch_normalization_957[0][0]
# __________________________________________________________________________________________________
# activation_958 (Activation)     (None, 25, 25, 64)   0           batch_normalization_958[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 25, 25, 288)  0           activation_952[0][0]
#                                                                  activation_954[0][0]
#                                                                  activation_957[0][0]
#                                                                  activation_958[0][0]
# __________________________________________________________________________________________________
# conv2d_962 (Conv2D)             (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_962 (BatchN (None, 25, 25, 64)   192         conv2d_962[0][0]
# __________________________________________________________________________________________________
# activation_962 (Activation)     (None, 25, 25, 64)   0           batch_normalization_962[0][0]
# __________________________________________________________________________________________________
# conv2d_960 (Conv2D)             (None, 25, 25, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_963 (Conv2D)             (None, 25, 25, 96)   55296       activation_962[0][0]
# __________________________________________________________________________________________________
# batch_normalization_960 (BatchN (None, 25, 25, 48)   144         conv2d_960[0][0]
# __________________________________________________________________________________________________
# batch_normalization_963 (BatchN (None, 25, 25, 96)   288         conv2d_963[0][0]
# __________________________________________________________________________________________________
# activation_960 (Activation)     (None, 25, 25, 48)   0           batch_normalization_960[0][0]
# __________________________________________________________________________________________________
# activation_963 (Activation)     (None, 25, 25, 96)   0           batch_normalization_963[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_92 (AveragePo (None, 25, 25, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_959 (Conv2D)             (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_961 (Conv2D)             (None, 25, 25, 64)   76800       activation_960[0][0]
# __________________________________________________________________________________________________
# conv2d_964 (Conv2D)             (None, 25, 25, 96)   82944       activation_963[0][0]
# __________________________________________________________________________________________________
# conv2d_965 (Conv2D)             (None, 25, 25, 64)   18432       average_pooling2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_959 (BatchN (None, 25, 25, 64)   192         conv2d_959[0][0]
# __________________________________________________________________________________________________
# batch_normalization_961 (BatchN (None, 25, 25, 64)   192         conv2d_961[0][0]
# __________________________________________________________________________________________________
# batch_normalization_964 (BatchN (None, 25, 25, 96)   288         conv2d_964[0][0]
# __________________________________________________________________________________________________
# batch_normalization_965 (BatchN (None, 25, 25, 64)   192         conv2d_965[0][0]
# __________________________________________________________________________________________________
# activation_959 (Activation)     (None, 25, 25, 64)   0           batch_normalization_959[0][0]
# __________________________________________________________________________________________________
# activation_961 (Activation)     (None, 25, 25, 64)   0           batch_normalization_961[0][0]
# __________________________________________________________________________________________________
# activation_964 (Activation)     (None, 25, 25, 96)   0           batch_normalization_964[0][0]
# __________________________________________________________________________________________________
# activation_965 (Activation)     (None, 25, 25, 64)   0           batch_normalization_965[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 25, 25, 288)  0           activation_959[0][0]
#                                                                  activation_961[0][0]
#                                                                  activation_964[0][0]
#                                                                  activation_965[0][0]
# __________________________________________________________________________________________________
# conv2d_967 (Conv2D)             (None, 25, 25, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_967 (BatchN (None, 25, 25, 64)   192         conv2d_967[0][0]
# __________________________________________________________________________________________________
# activation_967 (Activation)     (None, 25, 25, 64)   0           batch_normalization_967[0][0]
# __________________________________________________________________________________________________
# conv2d_968 (Conv2D)             (None, 25, 25, 96)   55296       activation_967[0][0]
# __________________________________________________________________________________________________
# batch_normalization_968 (BatchN (None, 25, 25, 96)   288         conv2d_968[0][0]
# __________________________________________________________________________________________________
# activation_968 (Activation)     (None, 25, 25, 96)   0           batch_normalization_968[0][0]
# __________________________________________________________________________________________________
# conv2d_966 (Conv2D)             (None, 12, 12, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_969 (Conv2D)             (None, 12, 12, 96)   82944       activation_968[0][0]
# __________________________________________________________________________________________________
# batch_normalization_966 (BatchN (None, 12, 12, 384)  1152        conv2d_966[0][0]
# __________________________________________________________________________________________________
# batch_normalization_969 (BatchN (None, 12, 12, 96)   288         conv2d_969[0][0]
# __________________________________________________________________________________________________
# activation_966 (Activation)     (None, 12, 12, 384)  0           batch_normalization_966[0][0]
# __________________________________________________________________________________________________
# activation_969 (Activation)     (None, 12, 12, 96)   0           batch_normalization_969[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_42 (MaxPooling2D) (None, 12, 12, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 12, 12, 768)  0           activation_966[0][0]
#                                                                  activation_969[0][0]
#                                                                  max_pooling2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_974 (Conv2D)             (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_974 (BatchN (None, 12, 12, 128)  384         conv2d_974[0][0]
# __________________________________________________________________________________________________
# activation_974 (Activation)     (None, 12, 12, 128)  0           batch_normalization_974[0][0]
# __________________________________________________________________________________________________
# conv2d_975 (Conv2D)             (None, 12, 12, 128)  114688      activation_974[0][0]
# __________________________________________________________________________________________________
# batch_normalization_975 (BatchN (None, 12, 12, 128)  384         conv2d_975[0][0]
# __________________________________________________________________________________________________
# activation_975 (Activation)     (None, 12, 12, 128)  0           batch_normalization_975[0][0]
# __________________________________________________________________________________________________
# conv2d_971 (Conv2D)             (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_976 (Conv2D)             (None, 12, 12, 128)  114688      activation_975[0][0]
# __________________________________________________________________________________________________
# batch_normalization_971 (BatchN (None, 12, 12, 128)  384         conv2d_971[0][0]
# __________________________________________________________________________________________________
# batch_normalization_976 (BatchN (None, 12, 12, 128)  384         conv2d_976[0][0]
# __________________________________________________________________________________________________
# activation_971 (Activation)     (None, 12, 12, 128)  0           batch_normalization_971[0][0]
# __________________________________________________________________________________________________
# activation_976 (Activation)     (None, 12, 12, 128)  0           batch_normalization_976[0][0]
# __________________________________________________________________________________________________
# conv2d_972 (Conv2D)             (None, 12, 12, 128)  114688      activation_971[0][0]
# __________________________________________________________________________________________________
# conv2d_977 (Conv2D)             (None, 12, 12, 128)  114688      activation_976[0][0]
# __________________________________________________________________________________________________
# batch_normalization_972 (BatchN (None, 12, 12, 128)  384         conv2d_972[0][0]
# __________________________________________________________________________________________________
# batch_normalization_977 (BatchN (None, 12, 12, 128)  384         conv2d_977[0][0]
# __________________________________________________________________________________________________
# activation_972 (Activation)     (None, 12, 12, 128)  0           batch_normalization_972[0][0]
# __________________________________________________________________________________________________
# activation_977 (Activation)     (None, 12, 12, 128)  0           batch_normalization_977[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_93 (AveragePo (None, 12, 12, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_970 (Conv2D)             (None, 12, 12, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_973 (Conv2D)             (None, 12, 12, 192)  172032      activation_972[0][0]
# __________________________________________________________________________________________________
# conv2d_978 (Conv2D)             (None, 12, 12, 192)  172032      activation_977[0][0]
# __________________________________________________________________________________________________
# conv2d_979 (Conv2D)             (None, 12, 12, 192)  147456      average_pooling2d_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_970 (BatchN (None, 12, 12, 192)  576         conv2d_970[0][0]
# __________________________________________________________________________________________________
# batch_normalization_973 (BatchN (None, 12, 12, 192)  576         conv2d_973[0][0]
# __________________________________________________________________________________________________
# batch_normalization_978 (BatchN (None, 12, 12, 192)  576         conv2d_978[0][0]
# __________________________________________________________________________________________________
# batch_normalization_979 (BatchN (None, 12, 12, 192)  576         conv2d_979[0][0]
# __________________________________________________________________________________________________
# activation_970 (Activation)     (None, 12, 12, 192)  0           batch_normalization_970[0][0]
# __________________________________________________________________________________________________
# activation_973 (Activation)     (None, 12, 12, 192)  0           batch_normalization_973[0][0]
# __________________________________________________________________________________________________
# activation_978 (Activation)     (None, 12, 12, 192)  0           batch_normalization_978[0][0]
# __________________________________________________________________________________________________
# activation_979 (Activation)     (None, 12, 12, 192)  0           batch_normalization_979[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 12, 12, 768)  0           activation_970[0][0]
#                                                                  activation_973[0][0]
#                                                                  activation_978[0][0]
#                                                                  activation_979[0][0]
# __________________________________________________________________________________________________
# conv2d_984 (Conv2D)             (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_984 (BatchN (None, 12, 12, 160)  480         conv2d_984[0][0]
# __________________________________________________________________________________________________
# activation_984 (Activation)     (None, 12, 12, 160)  0           batch_normalization_984[0][0]
# __________________________________________________________________________________________________
# conv2d_985 (Conv2D)             (None, 12, 12, 160)  179200      activation_984[0][0]
# __________________________________________________________________________________________________
# batch_normalization_985 (BatchN (None, 12, 12, 160)  480         conv2d_985[0][0]
# __________________________________________________________________________________________________
# activation_985 (Activation)     (None, 12, 12, 160)  0           batch_normalization_985[0][0]
# __________________________________________________________________________________________________
# conv2d_981 (Conv2D)             (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_986 (Conv2D)             (None, 12, 12, 160)  179200      activation_985[0][0]
# __________________________________________________________________________________________________
# batch_normalization_981 (BatchN (None, 12, 12, 160)  480         conv2d_981[0][0]
# __________________________________________________________________________________________________
# batch_normalization_986 (BatchN (None, 12, 12, 160)  480         conv2d_986[0][0]
# __________________________________________________________________________________________________
# activation_981 (Activation)     (None, 12, 12, 160)  0           batch_normalization_981[0][0]
# __________________________________________________________________________________________________
# activation_986 (Activation)     (None, 12, 12, 160)  0           batch_normalization_986[0][0]
# __________________________________________________________________________________________________
# conv2d_982 (Conv2D)             (None, 12, 12, 160)  179200      activation_981[0][0]
# __________________________________________________________________________________________________
# conv2d_987 (Conv2D)             (None, 12, 12, 160)  179200      activation_986[0][0]
# __________________________________________________________________________________________________
# batch_normalization_982 (BatchN (None, 12, 12, 160)  480         conv2d_982[0][0]
# __________________________________________________________________________________________________
# batch_normalization_987 (BatchN (None, 12, 12, 160)  480         conv2d_987[0][0]
# __________________________________________________________________________________________________
# activation_982 (Activation)     (None, 12, 12, 160)  0           batch_normalization_982[0][0]
# __________________________________________________________________________________________________
# activation_987 (Activation)     (None, 12, 12, 160)  0           batch_normalization_987[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_94 (AveragePo (None, 12, 12, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_980 (Conv2D)             (None, 12, 12, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_983 (Conv2D)             (None, 12, 12, 192)  215040      activation_982[0][0]
# __________________________________________________________________________________________________
# conv2d_988 (Conv2D)             (None, 12, 12, 192)  215040      activation_987[0][0]
# __________________________________________________________________________________________________
# conv2d_989 (Conv2D)             (None, 12, 12, 192)  147456      average_pooling2d_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_980 (BatchN (None, 12, 12, 192)  576         conv2d_980[0][0]
# __________________________________________________________________________________________________
# batch_normalization_983 (BatchN (None, 12, 12, 192)  576         conv2d_983[0][0]
# __________________________________________________________________________________________________
# batch_normalization_988 (BatchN (None, 12, 12, 192)  576         conv2d_988[0][0]
# __________________________________________________________________________________________________
# batch_normalization_989 (BatchN (None, 12, 12, 192)  576         conv2d_989[0][0]
# __________________________________________________________________________________________________
# activation_980 (Activation)     (None, 12, 12, 192)  0           batch_normalization_980[0][0]
# __________________________________________________________________________________________________
# activation_983 (Activation)     (None, 12, 12, 192)  0           batch_normalization_983[0][0]
# __________________________________________________________________________________________________
# activation_988 (Activation)     (None, 12, 12, 192)  0           batch_normalization_988[0][0]
# __________________________________________________________________________________________________
# activation_989 (Activation)     (None, 12, 12, 192)  0           batch_normalization_989[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 12, 12, 768)  0           activation_980[0][0]
#                                                                  activation_983[0][0]
#                                                                  activation_988[0][0]
#                                                                  activation_989[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 110592)       0           mixed5[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 512)          56623616    flatten_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 512)          0           dense_24[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 5)            2565        dropout_12[0][0]
# ==================================================================================================
# Total params: 61,764,837
# Trainable params: 56,626,181
# Non-trainable params: 5,138,656
# __________________________________________________________________________________________________

# %%
history = model2.fit(train_generator, 
                     epochs=20, 
                     steps_per_epoch=10, 
                     validation_data=val_generator, 
                     validation_steps=3,
                     verbose=1)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 33s 3s/step - loss: 3.9526 - accuracy: 0.3656 - val_loss: 1.2377 - val_accuracy: 0.5521
# Epoch 2/20
# 10/10 [==============================] - 8s 864ms/step - loss: 1.1802 - accuracy: 0.6094 - val_loss: 1.7509 - val_accuracy: 0.5625
# Epoch 3/20
# 10/10 [==============================] - 8s 826ms/step - loss: 0.8094 - accuracy: 0.6812 - val_loss: 1.0154 - val_accuracy: 0.7083
# Epoch 4/20
# 10/10 [==============================] - 8s 820ms/step - loss: 0.5733 - accuracy: 0.7844 - val_loss: 1.1372 - val_accuracy: 0.6771
# Epoch 5/20
# 10/10 [==============================] - 9s 881ms/step - loss: 0.4713 - accuracy: 0.8219 - val_loss: 1.2124 - val_accuracy: 0.6771
# Epoch 6/20
# 10/10 [==============================] - 9s 860ms/step - loss: 0.4839 - accuracy: 0.8000 - val_loss: 1.2363 - val_accuracy: 0.6354
# Epoch 7/20
# 10/10 [==============================] - 8s 829ms/step - loss: 0.4879 - accuracy: 0.8156 - val_loss: 1.0530 - val_accuracy: 0.5938
# Epoch 8/20
# 10/10 [==============================] - 8s 834ms/step - loss: 0.4745 - accuracy: 0.8031 - val_loss: 1.1719 - val_accuracy: 0.6562
# Epoch 9/20
# 10/10 [==============================] - 9s 935ms/step - loss: 0.3437 - accuracy: 0.8719 - val_loss: 0.9307 - val_accuracy: 0.7188
# Epoch 10/20
# 10/10 [==============================] - 9s 925ms/step - loss: 0.3599 - accuracy: 0.8781 - val_loss: 1.0401 - val_accuracy: 0.6979
# Epoch 11/20
# 10/10 [==============================] - 9s 934ms/step - loss: 0.4110 - accuracy: 0.8219 - val_loss: 1.0745 - val_accuracy: 0.6979
# Epoch 12/20
# 10/10 [==============================] - 8s 855ms/step - loss: 0.3116 - accuracy: 0.8781 - val_loss: 1.3132 - val_accuracy: 0.6979
# Epoch 13/20
# 10/10 [==============================] - 9s 847ms/step - loss: 0.3134 - accuracy: 0.8719 - val_loss: 1.3923 - val_accuracy: 0.6875
# Epoch 14/20
# 10/10 [==============================] - 9s 893ms/step - loss: 0.2954 - accuracy: 0.8813 - val_loss: 1.2532 - val_accuracy: 0.6667
# Epoch 15/20
# 10/10 [==============================] - 9s 894ms/step - loss: 0.3472 - accuracy: 0.8594 - val_loss: 1.1559 - val_accuracy: 0.7292
# Epoch 16/20
# 10/10 [==============================] - 8s 832ms/step - loss: 0.2886 - accuracy: 0.8906 - val_loss: 1.3121 - val_accuracy: 0.6875
# Epoch 17/20
# 10/10 [==============================] - 9s 878ms/step - loss: 0.2826 - accuracy: 0.8906 - val_loss: 0.9351 - val_accuracy: 0.7083
# Epoch 18/20
# 10/10 [==============================] - 9s 900ms/step - loss: 0.3041 - accuracy: 0.9000 - val_loss: 1.1038 - val_accuracy: 0.6354
# Epoch 19/20
# 10/10 [==============================] - 8s 804ms/step - loss: 0.3034 - accuracy: 0.8781 - val_loss: 1.2276 - val_accuracy: 0.7188
# Epoch 20/20
# 10/10 [==============================] - 8s 812ms/step - loss: 0.2800 - accuracy: 0.8813 - val_loss: 1.0420 - val_accuracy: 0.7083

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc)) # Get number of epochs

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
loss = model2.evaluate(test_generator, steps=10)
# Out:
# 10/10 [==============================] - 12s 1s/step - loss: 0.4499 - accuracy: 0.8452

# %% [markdown]
# ### **Save the Model**

# %%
saved_model_path = "/content/best_model.h5"

# Save model h5
model2.save(saved_model_path)

# %% [markdown]
# ### **Convert Saved Model to Tensorflow.js**

# %%
# !tensorflowjs_converter --input_format=keras {saved_model_path} '/content/drive/MyDrive/best_model_fix'
# Out:
# 2021-05-30 03:17:54.899069: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
